# %% [markdown]
# <a href="https://colab.research.google.com/github/mrdantzig/nlp-bible-code/blob/master/06%EC%9E%A5_%EC%9D%98%EC%A1%B4%EB%B6%84%EC%84%9D/%5B6-2%5D%20Spacy%EB%A5%BC%20%EC%9D%B4%EC%9A%A9%ED%95%9C%20%EC%9D%98%EC%A1%B4%20%EA%B5%AC%EB%AC%B8%20%EB%B6%84%EC%84%9D_%EC%88%98%EC%A0%95%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # spaCy를 이용한 의존 구문 분석
#
# 이 실습은 원본 예제와 같은 흐름을 유지하면서, 현재 Google Colab(Python 3.13)에서 실행되도록 수정한 버전입니다.
#
# - 원본: spaCy 2.1.9 기준
# - 수정본: 최신 spaCy 3.x 및 `en_core_web_sm` 모델 기준
# - 분석 대상: 영어 문장

# %% [markdown]
# ## 1. 패키지 설치
#
# 원본 예제는 오래된 spaCy 2.1.9를 설치하지만, 현재 Python 3.13에서는 사용할 수 없습니다. 따라서 최신 spaCy를 설치합니다.

# %%
# %pip install -U spacy

# %% [markdown]
# ## 2. 영어 모델 설치
#
# spaCy 본체와 영어 분석 모델은 별도로 설치합니다.

# %%
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 81.2 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %% [markdown]
# ## 3. 패키지 불러오기
#
# 원본 예제와 동일한 단계입니다.

# %%
import sys
import spacy
from spacy import displacy

print("Python:", sys.version.split()[0])
print("spaCy:", spacy.__version__)
# Out:
# Python: 3.13.15
# spaCy: 3.8.16

# %% [markdown]
# ## 4. 영어 모델 불러오기

# %%
nlp = spacy.load("en_core_web_sm")
print("모델 로드 완료")
# Out:
# 모델 로드 완료

# %% [markdown]
# ## 5. 분석 문장 지정
#
# 원본 예제의 문장을 그대로 사용합니다.

# %%
text = "The fat cat sat on the mat. The big dog jogged past a log."
print(text)
# Out:
# The fat cat sat on the mat. The big dog jogged past a log.

# %% [markdown]
# ## 6. 문장 분석

# %%
doc = nlp(text)
print(doc)
# Out:
# The fat cat sat on the mat. The big dog jogged past a log.

# %% [markdown]
# ## 7. 토큰 출력

# %%
for token in doc:
    print(token.text)
# Out:
# The
# fat
# cat
# sat
# on
# the
# mat
# .
# The
# big
# dog
# jogged
# past
# a
# log
# .

# %% [markdown]
# ## 8. 토큰의 품사와 표제어 출력

# %%
for token in doc:
    print(
        token.text,
        token.lemma_,
        token.pos_,
        token.tag_,
        token.is_stop
    )
# Out:
# The the DET DT True
# fat fat ADJ JJ False
# cat cat NOUN NN False
# sat sit VERB VBD False
# on on ADP IN True
# the the DET DT True
# mat mat NOUN NN False
# . . PUNCT . False
# The the DET DT True
# big big ADJ JJ False
# dog dog NOUN NN False
# jogged jog VERB VBD False
# past past ADP IN False
# a a DET DT True
# log log NOUN NN False
# . . PUNCT . False

# %% [markdown]
# ## 9. 의존 관계 출력
#
# `token.dep_`는 의존 관계, `token.head.text`는 해당 토큰의 중심어입니다.

# %%
for token in doc:
    print(token.text, token.dep_, token.head.text)
# Out:
# The det cat
# fat amod cat
# cat nsubj sat
# sat ROOT sat
# on prep sat
# the det mat
# mat pobj on
# . punct sat
# The det dog
# big amod dog
# dog nsubj jogged
# jogged ROOT jogged
# past prep jogged
# a det log
# log pobj past
# . punct jogged

# %% [markdown]
# ## 10. 분석 결과를 표로 정리

# %%
import pandas as pd

rows = []
for token in doc:
    rows.append({
        "토큰": token.text,
        "표제어": token.lemma_,
        "품사": token.pos_,
        "세부품사": token.tag_,
        "의존관계": token.dep_,
        "중심어": token.head.text,
        "불용어": token.is_stop
    })

df = pd.DataFrame(rows)
df
# Out:
#         토큰   표제어     품사 세부품사   의존관계     중심어    불용어
# 0      The   the    DET   DT    det     cat   True
# 1      fat   fat    ADJ   JJ   amod     cat  False
# 2      cat   cat   NOUN   NN  nsubj     sat  False
# 3      sat   sit   VERB  VBD   ROOT     sat  False
# 4       on    on    ADP   IN   prep     sat   True
# 5      the   the    DET   DT    det     mat   True
# 6      mat   mat   NOUN   NN   pobj      on  False
# 7        .     .  PUNCT    .  punct     sat  False
# 8      The   the    DET   DT    det     dog   True
# 9      big   big    ADJ   JJ   amod     dog  False
# 10     dog   dog   NOUN   NN  nsubj  jogged  False
# 11  jogged   jog   VERB  VBD   ROOT  jogged  False
# 12    past  past    ADP   IN   prep  jogged  False
# 13       a     a    DET   DT    det     log   True
# 14     log   log   NOUN   NN   pobj    past  False
# 15       .     .  PUNCT    .  punct  jogged  False

# %% [markdown]
# ## 11. 의존 구문 분석 시각화

# %%
displacy.render(doc, style="dep", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="dd656bdb0e494dcba3b28f48bf898854-0" class="displacy" width="2500" height="312.0" direction="ltr" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">fat</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
# ...

# %% [markdown]
# ## 12. 시각화 옵션 적용

# %%
options = {"compact": True, "distance": 100}

displacy.render(
    doc,
    style="dep",
    jupyter=True,
    options=options
)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="f9af2bc1a0024e2088b83939c7cfdd75-0" class="displacy" width="1450" height="237.0" direction="ltr" style="max-width: none; height: 237.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">fat</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
# ...

# %% [markdown]
# ## 13. 모델 및 파이프라인 확인

# %%
print(nlp.pipe_names)
print("문장 수:", len(list(doc.sents)))
# Out:
# ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']
# 문장 수: 2

# %% [markdown]
# ## 정리
#
# 원본 예제의 토큰 분석, 품사 분석, 의존 관계 출력, 의존 구문 시각화 순서를 유지했습니다. 변경된 부분은 오래된 `spacy==2.1.9` 설치를 최신 spaCy 설치로 바꾼 것과 영어 모델 설치 셀을 명시적으로 추가한 것입니다.
